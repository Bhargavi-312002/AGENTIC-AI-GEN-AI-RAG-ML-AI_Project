# %% [markdown]
# # Operators

# %% [raw]
# The action performed on the operands are called as operators
#
# Syntax: opcode=operand operator operand
#         c=a+b
#
# There are 5 operators in python
#
# 1. Arithematic operator
# 2.assignment operator
# 3.relational operator
# 4.logiacl operator
# 5.unary operator

# %% [markdown]
# ### 1. Arithematic operator

# %% [raw]
# The arithematic operator are used to perform the arithematic operations such as +,-,*,/,//,%,**

# %%
print("a+b =",4+5)
print("a-b =",4-5)
print("a*b =",4*5)
print("a/b =",4/5)
print("a//b =",4//5)
print("a%b =",4%5)
print("a**b=",4**5)
# Out:
# a+b = 9
# a-b = -1
# a*b = 20
# a/b = 0.8
# a//b = 0
# a%b = 4
# a**b= 1024

# %% [markdown]
# ### 2. Assignment operator

# %% [raw]
# The assignment operator are used to assign the values such as +=,-=,*=,/=,//=

# %%
a=5
b=6
c=3
d=8
e=5
f=10
g=14
h=4
i=2
a+=2
b-=4
c*=5
d*=10
e/=2
g//=2
h%=3
i**=4
print('a+=2 =',a)
print('b-=4 =',b)
print('c*=5 =',c)
print('d*=10 =',d)
print('e/=2 =',e)
print('g//=2 =',g)
print('h%=3 =',h)
print('i**=4 =',i)
# Out:
# a+=2 = 7
# b-=4 = 2
# c*=5 = 15
# d*=10 = 80
# e/=2 = 2.5
# g//=2 = 7
# h%=3 = 1
# i**=4 = 16

# %% [markdown]
# ### 3. Relational operation

# %% [raw]
# The relational operators are used for comparision and provide output True or False

# %%
a=10
b=20
print('a<b =',a<b)
print('a>b =',a>b)
print('a<=b =',a<=b)
print('a>=b =',a>=b)
print('a==b =',a==b)
print('a!=b =',a!=b)
# Out:
# a<b = True
# a>b = False
# a<=b = True
# a>=b = False
# a==b = False
# a!=b = True

# %% [markdown]
# ### 4. Logical operations

# %% [raw]
# The logical operators are used to perform the logical AND,OR and NOT operations on the variables
#
# For logical AND the output will be true if both the inputs are true else the output will be false.
# For logical OR the output will be true if one of the input is true.

# %%
a=10
b=20
print('And:',a<b and b<a)
print('OR:',a<b or b<a)
print('Not:',not a)
# Out:
# And: False
# OR: True
# Not: False

# %%
a=0
b=20
print('And:',a<b and b<a)
print('OR:',a<b or b<a)
print('Not:',not a)
# Out:
# And: False
# OR: True
# Not: True

# %% [markdown]
# ### 5.Unary operator

# %% [raw]
# '-' is the unary operator performed on the single variable

# %%
a = -7
m=a
print(m)
print(a)
# Out:
# -7
# -7

# %%
a =7
m= -(a)
print(m)
print(a)
# Out:
# -7
# 7
